# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
#Setting the figure style and size
plt.style.use('ggplot')
plt.rcParams["figure.figsize"] = [16,9]

# %%
#loading the data
df = pd.read_csv('PRSA_data.csv')

# %%
# We can see the year, month, day and hour can be combined to show the data & Time 
df["datetime"] = pd.to_datetime(df[['year', 'month', 'day', 'hour']])

# %%
df.head()
# Out:
#    No  year  month  day  hour  DEWP  TEMP    PRES cbwd    Iws  Is  Ir  pm2.5  \
# 0   1  2010      1    1     0   -21 -11.0  1021.0   NW   1.79   0   0    NaN
# 1   2  2010      1    1     1   -21 -12.0  1020.0   NW   4.92   0   0    NaN
# 2   3  2010      1    1     2   -21 -11.0  1019.0   NW   6.71   0   0    NaN
# 3   4  2010      1    1     3   -21 -14.0  1019.0   NW   9.84   0   0    NaN
# 4   5  2010      1    1     4   -20 -12.0  1018.0   NW  12.97   0   0    NaN
#
#              datetime
# 0 2010-01-01 00:00:00
# 1 2010-01-01 01:00:00
# 2 2010-01-01 02:00:00
# 3 2010-01-01 03:00:00
# 4 2010-01-01 04:00:00

# %%
cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
df = df[cols]

# %%
df.head()
# Out:
#              datetime  No  year  month  day  hour  DEWP  TEMP    PRES cbwd  \
# 0 2010-01-01 00:00:00   1  2010      1    1     0   -21 -11.0  1021.0   NW
# 1 2010-01-01 01:00:00   2  2010      1    1     1   -21 -12.0  1020.0   NW
# 2 2010-01-01 02:00:00   3  2010      1    1     2   -21 -11.0  1019.0   NW
# 3 2010-01-01 03:00:00   4  2010      1    1     3   -21 -14.0  1019.0   NW
# 4 2010-01-01 04:00:00   5  2010      1    1     4   -20 -12.0  1018.0   NW
#
#      Iws  Is  Ir  pm2.5
# 0   1.79   0   0    NaN
# 1   4.92   0   0    NaN
# 2   6.71   0   0    NaN
# 3   9.84   0   0    NaN
# 4  12.97   0   0    NaN

# %%
#time series visualization
def time_series(start, end):
    time_series_df = df[['datetime', 'pm2.5']][(df['datetime'] >= start) & (df['datetime'] <= end)]
    x = time_series_df['datetime']
    y = time_series_df['pm2.5']
    plt.plot(x,y)
    plt.xlabel('Time')
    plt.ylabel('PM2.5 Value')
    plt.title('PM2.5 Time Series')
    return plt.show();

# %%
#Visualizing the data for the given years
time_series('2010','2014')

# %%
# Select the time frame from the graph above
filter = df[['datetime', 'pm2.5']][(df['pm2.5'] >= 500)]
filter.head()
# Out:
#                 datetime  pm2.5
# 1057 2010-02-14 01:00:00  980.0
# 1059 2010-02-14 03:00:00  599.0
# 1876 2010-03-20 04:00:00  700.0
# 1930 2010-03-22 10:00:00  784.0
# 1931 2010-03-22 11:00:00  761.0

# %%
# Select the time frame from the graph above
df[['datetime', 'pm2.5']][(df['datetime'] >= '2010-02-14 00:00:00') & (df['datetime'] <= '2010-02-14 23:00:00')]
# Out:
#                 datetime  pm2.5
# 1056 2010-02-14 00:00:00  351.0
# 1057 2010-02-14 01:00:00  980.0
# 1058 2010-02-14 02:00:00    NaN
# 1059 2010-02-14 03:00:00  599.0
# 1060 2010-02-14 04:00:00   39.0
# 1061 2010-02-14 05:00:00    7.0
# 1062 2010-02-14 06:00:00    8.0
# 1063 2010-02-14 07:00:00    7.0
# 1064 2010-02-14 08:00:00    7.0
# 1065 2010-02-14 09:00:00    7.0
# 1066 2010-02-14 10:00:00   16.0
# 1067 2010-02-14 11:00:00   19.0
# 1068 2010-02-14 12:00:00   15.0
# 1069 2010-02-14 13:00:00   21.0
# 1070 2010-02-14 14:00:00   18.0
# 1071 2010-02-14 15:00:00   16.0
# 1072 2010-02-14 16:00:00   15.0
# 1073 2010-02-14 17:00:00   16.0
# 1074 2010-02-14 18:00:00   16.0
# 1075 2010-02-14 19:00:00   21.0
# 1076 2010-02-14 20:00:00   36.0
# 1077 2010-02-14 21:00:00   51.0
# 1078 2010-02-14 22:00:00   67.0
# 1079 2010-02-14 23:00:00   46.0

# %%
df1[['datetime', 'pm2.5']][(df1['datetime'] >= '2011-02-03 00:00:00') & (df1['datetime'] <= '2011-02-03 23:00:00') & (df1["pm2.5"]>=200)]
# Out:
#                 datetime  pm2.5
# 9553 2011-02-03 01:00:00  348.0
# 9573 2011-02-03 21:00:00  250.0
# 9574 2011-02-03 22:00:00  288.0
# 9575 2011-02-03 23:00:00  289.0

# %%
# Select the time frame from the graph above
df[['datetime', 'pm2.5']][(df['datetime'] >= '2010-02-14 01:00:00') & (df['datetime'] <= '2010-02-14 03:00:00')]
# Out:
#                 datetime  pm2.5
# 1057 2010-02-14 01:00:00  980.0
# 1058 2010-02-14 02:00:00    NaN
# 1059 2010-02-14 03:00:00  599.0

# %%
# Select the time frame from the graph above
df[['datetime', 'pm2.5']][(df['datetime'] >= '2011-02-03 00:00:00') & (df['datetime'] <= '2011-02-03 23:00:00')]
# Out:
#                 datetime  pm2.5
# 9552 2011-02-03 00:00:00   75.0
# 9553 2011-02-03 01:00:00  348.0
# 9554 2011-02-03 02:00:00   79.0
# 9555 2011-02-03 03:00:00   40.0
# 9556 2011-02-03 04:00:00   25.0
# 9557 2011-02-03 05:00:00   29.0
# 9558 2011-02-03 06:00:00   23.0
# 9559 2011-02-03 07:00:00   24.0
# 9560 2011-02-03 08:00:00   39.0
# 9561 2011-02-03 09:00:00   46.0
# 9562 2011-02-03 10:00:00   47.0
# 9563 2011-02-03 11:00:00   30.0
# 9564 2011-02-03 12:00:00   36.0
# 9565 2011-02-03 13:00:00   28.0
# 9566 2011-02-03 14:00:00   44.0
# 9567 2011-02-03 15:00:00   47.0
# 9568 2011-02-03 16:00:00   78.0
# 9569 2011-02-03 17:00:00  100.0
# 9570 2011-02-03 18:00:00  146.0
# 9571 2011-02-03 19:00:00  143.0
# 9572 2011-02-03 20:00:00  167.0
# 9573 2011-02-03 21:00:00  250.0
# 9574 2011-02-03 22:00:00  288.0
# 9575 2011-02-03 23:00:00  289.0

# %%
# Select the time frame from the graph above
df[['datetime', 'pm2.5']][(df['datetime'] >= '2011-02-03 00:00:00') & (df['datetime'] <= '2011-02-03 23:00:00') & (df['pm2.5'] >= 150)]
# Out:
#                 datetime  pm2.5
# 9553 2011-02-03 01:00:00  348.0
# 9572 2011-02-03 20:00:00  167.0
# 9573 2011-02-03 21:00:00  250.0
# 9574 2011-02-03 22:00:00  288.0
# 9575 2011-02-03 23:00:00  289.0

# %%
df[['datetime', 'pm2.5']][(df['datetime'] >= '2012-01-23 00:00:00') & (df['datetime'] <= '2012-01-23 23:00:00')]
# Out:
#                  datetime  pm2.5
# 18048 2012-01-23 00:00:00  225.0
# 18049 2012-01-23 01:00:00  994.0
# 18050 2012-01-23 02:00:00  972.0
# 18051 2012-01-23 03:00:00  430.0
# 18052 2012-01-23 04:00:00  296.0
# 18053 2012-01-23 05:00:00  284.0
# 18054 2012-01-23 06:00:00  285.0
# 18055 2012-01-23 07:00:00  223.0
# 18056 2012-01-23 08:00:00  141.0
# 18057 2012-01-23 09:00:00   66.0
# 18058 2012-01-23 10:00:00   33.0
# 18059 2012-01-23 11:00:00   36.0
# 18060 2012-01-23 12:00:00   27.0
# 18061 2012-01-23 13:00:00   27.0
# 18062 2012-01-23 14:00:00   20.0
# 18063 2012-01-23 15:00:00   32.0
# 18064 2012-01-23 16:00:00   24.0
# 18065 2012-01-23 17:00:00   13.0
# 18066 2012-01-23 18:00:00   24.0
# 18067 2012-01-23 19:00:00   88.0
# 18068 2012-01-23 20:00:00  103.0
# 18069 2012-01-23 21:00:00  200.0
# 18070 2012-01-23 22:00:00  157.0
# 18071 2012-01-23 23:00:00   97.0

# %%
# Select the time frame from the graph above
df[['datetime', 'pm2.5']][(df['datetime'] >= '2012-01-23 00:00:00') & (df['datetime'] <= '2012-01-23 23:00:00') & (df['pm2.5'] >= 150)]
# Out:
#                  datetime  pm2.5
# 18048 2012-01-23 00:00:00  225.0
# 18049 2012-01-23 01:00:00  994.0
# 18050 2012-01-23 02:00:00  972.0
# 18051 2012-01-23 03:00:00  430.0
# 18052 2012-01-23 04:00:00  296.0
# 18053 2012-01-23 05:00:00  284.0
# 18054 2012-01-23 06:00:00  285.0
# 18055 2012-01-23 07:00:00  223.0
# 18069 2012-01-23 21:00:00  200.0
# 18070 2012-01-23 22:00:00  157.0

# %%
# Select the time frame from the graph above
df[['datetime', 'pm2.5']][(df['datetime'] >= '2013-02-10 00:00:00') & (df['datetime'] <= '2013-02-10 23:00:00') & (df['pm2.5'] >= 150)]
# Out:
#                  datetime  pm2.5
# 27265 2013-02-10 01:00:00  419.0
# 27266 2013-02-10 02:00:00  209.0
# 27267 2013-02-10 03:00:00  185.0

# %%
# Select the time frame from the graph above
df[['datetime', 'pm2.5']][(df['datetime'] >= '2014-01-31 00:00:00') & (df['datetime'] <= '2014-01-31 23:00:00') & (df['pm2.5'] >= 150)]
# Out:
#                  datetime  pm2.5
# 35785 2014-01-31 01:00:00  469.0
# 35786 2014-01-31 02:00:00  344.0
# 35787 2014-01-31 03:00:00  281.0
# 35788 2014-01-31 04:00:00  209.0
# 35789 2014-01-31 05:00:00  150.0
# 35805 2014-01-31 21:00:00  155.0
# 35806 2014-01-31 22:00:00  167.0
# 35807 2014-01-31 23:00:00  180.0

# %%
#loading the data
df1 = pd.read_csv('PRSA_data_outlier.csv')

# %%
# We can see the year, month, day and hour can be combined to show the data & Time 
df1["datetime"] = pd.to_datetime(df1[['year', 'month', 'day', 'hour']])

# %%
#time series visualization
def time_series(start, end):
    time_series_df1 = df1[['datetime', 'pm2.5']][(df1['datetime'] >= start) & (df1['datetime'] <= end)]
    x = time_series_df1['datetime']
    y = time_series_df1['pm2.5']
    plt.plot(x,y)
    plt.xlabel('Time')
    plt.ylabel('PM2.5 Value')
    plt.title('PM2.5 Time Series')
    return plt.show();

# %%
#Visualizing the data for the given years
time_series('2010','2014')

# %%
df2 = pd.read_csv("PRSA_data_500.csv")

# %%
# We can see the year, month, day and hour can be combined to show the data & Time 
df2["datetime"] = pd.to_datetime(df2[['year', 'month', 'day', 'hour']])

# %%
#time series visualization
def time_series1(start, end):
    time_series_df2 = df2[['datetime', 'pm2.5']][(df2['datetime'] >= start) & (df2['datetime'] <= end)]
    x = time_series_df2['datetime']
    y = time_series_df2['pm2.5']
    plt.plot(x,y)
    plt.xlabel('Time')
    plt.ylabel('PM2.5 Value')
    plt.title('PM2.5 Time Series')
    return plt.show();

# %%
#Visualizing the data for the given years
time_series1('2010','2014')

# %%
time_series('2010-02-11','2010-02-17')

# %%
df2[['datetime', 'pm2.5']][(df2['datetime'] >= '2010-02-14 00:00:00') & (df2['datetime'] <= '2010-02-14 23:00:00') & (df2['pm2.5']>=200)]
# Out:
#                 datetime  pm2.5
# 1056 2010-02-14 00:00:00  351.0
# 1057 2010-02-14 01:00:00  980.0
# 1059 2010-02-14 03:00:00  599.0

# %%
time_series('2012-01-20','2012-01-26')

# %%
df2[['datetime', 'pm2.5']][(df2['datetime'] >= '2012-01-23 00:00:00') & (df2['datetime'] <= '2012-01-23 23:00:00') & (df2['pm2.5']>=200)]
# Out:
#                  datetime  pm2.5
# 18048 2012-01-23 00:00:00  225.0
# 18049 2012-01-23 01:00:00  994.0
# 18050 2012-01-23 02:00:00  972.0
# 18051 2012-01-23 03:00:00  430.0
# 18052 2012-01-23 04:00:00  296.0
# 18053 2012-01-23 05:00:00  284.0
# 18054 2012-01-23 06:00:00  285.0
# 18055 2012-01-23 07:00:00  223.0
# 18069 2012-01-23 21:00:00  200.0

# %%
time_series('2013-02-10','2013-02-12')

# %%
df2[['datetime', 'pm2.5']][(df2['datetime'] >= '2013-02-10 00:00:00') & (df2['datetime'] <= '2013-02-15 23:00:00') & (df2['pm2.5']>=200)]
# Out:
#                  datetime  pm2.5
# 27265 2013-02-10 01:00:00  419.0
# 27266 2013-02-10 02:00:00  209.0
# 27337 2013-02-13 01:00:00  229.0
# 27338 2013-02-13 02:00:00  246.0
# 27339 2013-02-13 03:00:00  263.0
# 27340 2013-02-13 04:00:00  267.0
# 27341 2013-02-13 05:00:00  282.0
# 27342 2013-02-13 06:00:00  290.0
# 27343 2013-02-13 07:00:00  304.0
# 27344 2013-02-13 08:00:00  307.0
# 27345 2013-02-13 09:00:00  326.0
# 27346 2013-02-13 10:00:00  352.0
# 27347 2013-02-13 11:00:00  341.0
# 27348 2013-02-13 12:00:00  344.0
# 27349 2013-02-13 13:00:00  365.0
# 27350 2013-02-13 14:00:00  348.0
# 27351 2013-02-13 15:00:00  330.0
# 27352 2013-02-13 16:00:00  334.0
# 27353 2013-02-13 17:00:00  320.0
# 27354 2013-02-13 18:00:00  292.0
# 27355 2013-02-13 19:00:00  312.0
# 27356 2013-02-13 20:00:00  296.0
# 27357 2013-02-13 21:00:00  293.0
# 27358 2013-02-13 22:00:00  344.0
# 27359 2013-02-13 23:00:00  384.0
# 27360 2013-02-14 00:00:00  392.0
# 27361 2013-02-14 01:00:00  374.0
# ...

# %% [markdown]
# ## OUTLIER ANALYSIS
#
# Observing the outliers – Major spikes were observed during the January and February months of every year.
# Digging deeper it was found that these days of spikes corresponded to the Chinese New Year.
# High value of pm2.5 observed – on these dates.

# %% [markdown]
# ![pic1.png](attachment:pic1.png)
